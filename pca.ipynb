# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
import tensorflow.keras.datasets.mnist as mnist

# Load MNIST dataset
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# Normalize the pixel values to be between 0 and 1
x_train_normalized = x_train / 255.0
x_test_normalized = x_test / 255.0

# Reshape the data into 2D arrays
x_train_2d = x_train_normalized.reshape(x_train_normalized.shape[0], -1)
x_test_2d = x_test_normalized.reshape(x_test_normalized.shape[0], -1)

# Print the shape of the data before PCA
print("Shape of training data before PCA:", x_train_2d.shape)
print("Shape of test data before PCA:", x_test_2d.shape)

# Apply PCA
pca = PCA(n_components=2)  # You can adjust the number of components as needed
x_train_pca = pca.fit_transform(x_train_2d)
# Print the shape of the data after PCA
print("Shape of training data after PCA:", x_train_pca.shape)

# Plot the data points in the reduced space
plt.figure(figsize=(10, 8))
plt.scatter(x_train_pca[:, 0], x_train_pca[:, 1], c=y_train, cmap=plt.cm.get_cmap('tab10', 10))
plt.colorbar(ticks=range(10))
plt.title('MNIST Dataset after PCA')
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.show()
# Out:
# Shape of training data before PCA: (60000, 784)
# Shape of test data before PCA: (10000, 784)
# Shape of training data after PCA: (60000, 2)
# /var/folders/9c/k2rvfmz92ld8z0rgrcsbrnl40000gn/T/ipykernel_7184/1558449395.py:29: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   plt.scatter(x_train_pca[:, 0], x_train_pca[:, 1], c=y_train, cmap=plt.cm.get_cmap('tab10', 10))

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
from sklearn.datasets import load_digits

# Load the digits dataset
digits = load_digits()

# Extract the data and labels
X = digits.data
y = digits.target

# Print the shape of the data before PCA
print("Shape of data before PCA:", X.shape)

# Apply PCA
pca = PCA(n_components=2)  # You can adjust the number of components as needed
X_pca = pca.fit_transform(X)

# Print the shape of the data after PCA
print("Shape of data after PCA:", X_pca.shape)

# Plot the data points in the reduced space
plt.figure(figsize=(10, 8))
plt.scatter(X_pca[:, 0], X_pca[:, 1], c=y, cmap=plt.cm.get_cmap('tab10', 10))
plt.colorbar(ticks=range(10))
plt.title('Digits Dataset after PCA')
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.show()
# Out:
# Shape of data before PCA: (1797, 64)
# Shape of data after PCA: (1797, 2)
# /var/folders/9c/k2rvfmz92ld8z0rgrcsbrnl40000gn/T/ipykernel_7184/3939427892.py:25: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   plt.scatter(X_pca[:, 0], X_pca[:, 1], c=y, cmap=plt.cm.get_cmap('tab10', 10))
